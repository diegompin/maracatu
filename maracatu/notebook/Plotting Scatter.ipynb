# %% [markdown]
# # Plotting Scatter with Maracatu

# %% [markdown]
# ## First, install using pip
# pip install maracatu

# %%
import numpy as np
import pandas as pd

# %%
x = np.random.multivariate_normal([0,0], [[1,.6],[.6,1]], 1000)
df = pd.DataFrame({'X': x[:,0], 'Y': x[:,1]})
df.head()
# Out:
#           X         Y
# 0 -0.284971 -1.239230
# 1  2.222103  1.864703
# 2  0.510184  0.653116
# 3  1.165271  0.019573
# 4  0.677717  1.073183

# %% [markdown]
# ## 1. Import maracatu

# %%
import maracatu as m

# %% [markdown]
# ## 2. Create a dictionary with parameters

# %%
par_base = {
    'xvar': 'X',
    'yvar': 'Y',
    'title': 'Plotting Scatter with Maracatu',
    'xlabel': 'X label',
    'ylabel': 'Y label',
    'alpha': 0.4,
    'grid': True, 
    'fig.tight_layout': True,
}

# %% [markdown]
# ## 3. Plot

# %%
plt_scatter = m.Scatter()
fig, ax, par_plot = plt_scatter.plot(df, par_base)
